# %% [markdown]
# # Early Heart Disease Prediction Detection Using Machine Learning Algorithms

# %% [markdown]
# ## Data Collection and Cleaning

# %%
# importing all the necessary libraries and classes
import pandas as edhd_pd
import matplotlib.pyplot as edhd_plot
import missingno as edhd_msno
import seaborn as edhd_sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading ckd dataset

edhd_DataFrame= edhd_pd.read_csv('EDHD_initial_dataset1.csv')
edhd_DataFrame
# Out:
#      age     sex                cp  trtbps  chol  fbs      restecg  thalachh  \
# 0     63    male      asymptomatic     145   233   No       normal       150
# 1     37    male  non-anginal pain     130   250  Yes  abnormality       187
# 2     41  female   atypical angina     130   204  Yes       normal       172
# 3     56    male   atypical angina     120   236  Yes  abnormality       178
# 4     57  female    typical angina     120   354  Yes  abnormality       163
# ..   ...     ...               ...     ...   ...  ...          ...       ...
# 298   57  female    typical angina     140   241  Yes  abnormality       123
# 299   45    male      asymptomatic     110   264  Yes  abnormality       132
# 300   68    male    typical angina     144   193   No  abnormality       141
# 301   57    male    typical angina     130   131  Yes  abnormality       115
# 302   57  female   atypical angina     130   236  Yes       normal       174
#
#      exng  oldpeak  slp  caa  thall  output
# ...

# %%
edhd_DataFrame.shape
# Out:
# (303, 14)

# %%
edhd_DataFrame.describe()
# Out:
#               age      trtbps        chol    thalachh        exng     oldpeak  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    0.326733    1.039604
# std      9.082101   17.538143   51.830751   22.905161    0.469794    1.161075
# min     29.000000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.000000    0.800000
# 75%     61.000000  140.000000  274.500000  166.000000    1.000000    1.600000
# max     77.000000  200.000000  564.000000  202.000000    1.000000    6.200000
#
#               slp         caa       thall      output
# count  303.000000  303.000000  303.000000  303.000000
# mean     1.399340    0.729373    2.313531    0.544554
# std      0.616226    1.022606    0.612277    0.498835
# ...

# %%
edhd_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    object
#  2   cp        303 non-null    object
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    object
#  6   restecg   303 non-null    object
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 33.3+ KB

# %%
#Finding Missing value in percentage
edhd_DataFrame.isnull().sum()/len(edhd_DataFrame)*100
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trtbps      0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalachh    0.0
# exng        0.0
# oldpeak     0.0
# slp         0.0
# caa         0.0
# thall       0.0
# output      0.0
# dtype: float64

# %%
#Finding Missing value 
edhd_msno.matrix(edhd_DataFrame,color=(0.1, 0.2, 0.4))
edhd_plot.figure(figsize=(6, 6))
edhd_plot.show()

# %%
edhd_DataFrame.rename(columns={'output': 'Heart Disease Prediction'}, inplace=True)
edhd_DataFrame
# Out:
#      age     sex                cp  trtbps  chol  fbs      restecg  thalachh  \
# 0     63    male      asymptomatic     145   233   No       normal       150
# 1     37    male  non-anginal pain     130   250  Yes  abnormality       187
# 2     41  female   atypical angina     130   204  Yes       normal       172
# 3     56    male   atypical angina     120   236  Yes  abnormality       178
# 4     57  female    typical angina     120   354  Yes  abnormality       163
# ..   ...     ...               ...     ...   ...  ...          ...       ...
# 298   57  female    typical angina     140   241  Yes  abnormality       123
# 299   45    male      asymptomatic     110   264  Yes  abnormality       132
# 300   68    male    typical angina     144   193   No  abnormality       141
# 301   57    male    typical angina     130   131  Yes  abnormality       115
# 302   57  female   atypical angina     130   236  Yes       normal       174
#
# ...

# %%
edhd_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       303 non-null    int64
#  1   sex                       303 non-null    object
#  2   cp                        303 non-null    object
#  3   trtbps                    303 non-null    int64
#  4   chol                      303 non-null    int64
#  5   fbs                       303 non-null    object
#  6   restecg                   303 non-null    object
#  7   thalachh                  303 non-null    int64
#  8   exng                      303 non-null    int64
#  9   oldpeak                   303 non-null    float64
#  10  slp                       303 non-null    int64
#  11  caa                       303 non-null    int64
#  12  thall                     303 non-null    int64
#  13  Heart Disease Prediction  303 non-null    int64
# ...

# %%
newedhd_DataFrame= edhd_pd.read_csv('column_description.txt',sep = ' -')
newedhd_DataFrame=newedhd_DataFrame.reset_index()
newedhd_DataFrame.columns=['cols','abb_col_names']
edhd_DataFrame.columns=newedhd_DataFrame['abb_col_names'].values
edhd_DataFrame.columns
edhd_DataFrame.to_csv('EDHD_initial_dataset1.csv', index=False)
edhd_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0    Age                                   303 non-null    int64
#  1    Sex                                   303 non-null    object
#  2    Chest Pain Type                       303 non-null    object
#  3    Resting Blood Pressure                303 non-null    int64
#  4    Cholesterol                           303 non-null    int64
#  5    Fasting Blood Sugar                   303 non-null    object
#  6    Resting Electrocardiographic Results  303 non-null    object
#  7    Maximum Heart Rate Achieved           303 non-null    int64
#  8    Exercise-Induced Angina               303 non-null    int64
#  9    ST Depression                         303 non-null    float64
# ...

# %%
edhd_DataFrame.to_csv('EDHD_cleaned.csv', index=False)
edhd_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0    Age                                   303 non-null    int64
#  1    Sex                                   303 non-null    object
#  2    Chest Pain Type                       303 non-null    object
#  3    Resting Blood Pressure                303 non-null    int64
#  4    Cholesterol                           303 non-null    int64
#  5    Fasting Blood Sugar                   303 non-null    object
#  6    Resting Electrocardiographic Results  303 non-null    object
#  7    Maximum Heart Rate Achieved           303 non-null    int64
#  8    Exercise-Induced Angina               303 non-null    int64
#  9    ST Depression                         303 non-null    float64
# ...

# %%
# Extracting categorical and numerical columns

categorical_columns = [featuredColumn for featuredColumn in edhd_DataFrame.columns if edhd_DataFrame[featuredColumn].dtype == 'object']
numerical_columns = [featuredColumn for featuredColumn in edhd_DataFrame.columns if edhd_DataFrame[featuredColumn].dtype != 'object']
categorical_columns
# Out:
# [' Sex',
#  ' Chest Pain Type',
#  ' Fasting Blood Sugar',
#  ' Resting Electrocardiographic Results']

# %%
numerical_columns
# Out:
# [' Age',
#  ' Resting Blood Pressure',
#  ' Cholesterol',
#  ' Maximum Heart Rate Achieved',
#  ' Exercise-Induced Angina',
#  ' ST Depression',
#  ' Slope of the Peak Exercise',
#  ' Number of Vessels',
#  ' Thalassemia',
#  ' Heart Disease']
